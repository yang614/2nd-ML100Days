# %% [markdown]
# 作業1： 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# https://www.kaggle.com/c/digit-recognizer
# 1. 你選的這組資料為何重要
# 以電腦視野辨識手寫數字，目前想到的實作就是智慧型手機上手寫辨識的功能，如果手寫書法能夠辨識，以想法上來說不管是圖形的或著聲音的形式，只要能夠轉成數字的形式，都要能夠辨識。是否是差在學習樣本數的差別而已?
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# http://yann.lecun.com/exdb/mnist/index.html
# MNIST ("Modified National Institute of Standards and Technology") is the de facto “hello world” dataset of computer vision. Since its release in 1999, this classic dataset of handwritten images has served as the basis for benchmarking classification algorithms.
# 3. 蒐集而來的資料型態為何
# 非結構化文字
# idx1-ubyte
# idx3-ubyte
# 4. 這組資料想解決的問題如何評估
# 透過實際辨識的結果的正確率來評估。
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 何謂提升業績，如何提升業績?
# 假設每個月的載客量達到一定的數量後，就算是有達成業績。
# 如何提升業績: 透過大部分顧客的習慣叫車時間，叫車地點來增加班次。
# 通常都是上下班一定最多，但是也最塞車，也要考慮壅塞程度來決定班次的數，也可以分析夜間叫車率。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 也許是透過訂車的app來做數據的收集。
# 3. 蒐集而來的資料型態為何
# 結構化的表格。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 只要有達到業績量就是成功。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    s = (y-yp)**2
    
    mse = MSE = sum(s) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 256.355
# The Mean absolute error is 12.471
